# %%
import pandas as pd

# %%
df_games = pd.read_parquet('../data/df_games.parquet')
df_reviews = pd.read_parquet('../data/processed/df_reviews.parquet')
df_items = pd.read_parquet('../data/processed/df_items.parquet')
piv_norm = pd.read_parquet('../data/piv_norm.parquet')
user_sim_df = pd.read_parquet('../data/user_sim_df.parquet')
item_sim_df = pd.read_parquet('../data/item_sim_df.parquet')
df_genre = pd.read_parquet('../data/df_genre.parquet')

# %%
df_genre.head()
# Out:
#              user_id  playtime_forever  genres  release_year
# 0  76561197970982479               6.0  Action          2000
# 1  76561197970982479               0.0  Action          1999
# 2  76561197970982479               7.0  Action          2003
# 3  76561197970982479               0.0  Action          2001
# 5  76561197970982479               0.0  Action          2000

# %%
df_genre
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 user_year_playtime = (df_genre.groupby(['user_id',['genres']])['playtime_forever'].sum(().apply(lambda x: x / 60)))
#       2 user_year_playtime
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:8872, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8869 if level is None and by is None:
#    8870     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8872 return DataFrameGroupBy(
#    8873     obj=self,
#    8874     keys=by,
#    8875     axis=axis,
#    8876     level=level,
#    8877     as_index=as_index,
#    8878     sort=sort,
#    8879     group_keys=group_keys,
#    8880     observed=observed,
#    8881     dropna=dropna,
#    8882 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1274, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1271 self.dropna = dropna
#    1273 if grouper is None:
# -> 1274     grouper, exclusions, obj = get_grouper(
#    1275         obj,
#    1276         keys,
#    1277         axis=axis,
#    1278         level=level,
#    1279         sort=sort,
#    1280         observed=False if observed is lib.no_default else observed,
#    1281         dropna=self.dropna,
#    1282     )
#    1284 if observed is lib.no_default:
#    1285     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/groupby/grouper.py:1020, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1015         in_axis = False
#    1017     # create the Grouping
#    1018     # allow us to passing the actual Grouping as the gpr
#    1019     ping = (
# -> 1020         Grouping(
#    1021             group_axis,
#    1022             gpr,
#    1023             obj=obj,
#    1024             level=level,
#    1025             sort=sort,
#    1026             observed=observed,
#    1027             in_axis=in_axis,
#    1028             dropna=dropna,
#    1029         )
#    1030         if not isinstance(gpr, Grouping)
#    1031         else gpr
#    1032     )
#    1034     groupings.append(ping)
#    1036 if len(groupings) == 0 and len(obj):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/groupby/grouper.py:541, in Grouping.__init__(self, index, grouper, obj, level, sort, observed, in_axis, dropna, uniques)
#     539 self.level = level
#     540 self._orig_grouper = grouper
# --> 541 grouping_vector = _convert_grouper(index, grouper)
#     542 self._all_grouper = None
#     543 self._orig_cats = None
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/groupby/grouper.py:1062, in _convert_grouper(axis, grouper)
#    1060 elif isinstance(grouper, (list, tuple, Index, Categorical, np.ndarray)):
#    1061     if len(grouper) != len(axis):
# -> 1062         raise ValueError("Grouper and axis must be same length")
#    1064     if isinstance(grouper, (list, tuple)):
#    1065         grouper = com.asarray_tuplesafe(grouper)
#
# ValueError: Grouper and axis must be same length

# %%
df_games.head()
# Out:
#        genres                title  release_year  price        id  developer
# 0      Action  Lost Summoner Kitty          2018   4.99  761140.0  Kotoshiro
# 1      Casual  Lost Summoner Kitty          2018   4.99  761140.0  Kotoshiro
# 2       Indie  Lost Summoner Kitty          2018   4.99  761140.0  Kotoshiro
# 3  Simulation  Lost Summoner Kitty          2018   4.99  761140.0  Kotoshiro
# 4    Strategy  Lost Summoner Kitty          2018   4.99  761140.0  Kotoshiro

# %%
df_items
# Out:
#                    user_id  items_count item_id  \
# 0        76561197970982479          277      10
# 1        76561197970982479          277      20
# 2        76561197970982479          277      30
# 3        76561197970982479          277      40
# 4        76561197970982479          277      50
# ...                    ...          ...     ...
# 5170009  76561198329548331            7  346330
# 5170010  76561198329548331            7  373330
# 5170011  76561198329548331            7  388490
# 5170012  76561198329548331            7  521570
# 5170013  76561198329548331            7  519140
#
#                              item_name  playtime_forever
# 0                       Counter-Strike               6.0
# 1                Team Fortress Classic               0.0
# 2                        Day of Defeat               7.0
# 3                   Deathmatch Classic               0.0
# 4            Half-Life: Opposing Force               0.0
# ...                                ...               ...
# 5170009                   BrainBread 2               0.0
# 5170010                    All Is Dust               0.0
# 5170011  One Way To Die: Steam Edition               3.0
# 5170012          You Have 10 Seconds 2               4.0
# 5170013                     Minds Eyes               3.0
#
# [5094092 rows x 5 columns]

# %%
def UserForGenre(genero:str):

  # Filter data for the given genre
  genre_data = df_genre[df_genre['genres'] == genero]

  # Calculate total playtime per user per year (assuming playtime_forever in minutes)
  user_year_playtime = (
      genre_data
      .groupby(['user_id', genre_data['release_year']])['playtime_forever']
      .sum()
      .apply(lambda x: x / 60)  # Convert minutes to hours
      .reset_index()
  )

  # Group by user ID and sum playtime across years
  user_playtime_total = user_year_playtime.groupby('user_id')['playtime_forever'].sum()

  # Find user with the most playtime
  top_user_id = user_playtime_total.idxmax()

  # Filter data for the top user
  top_user_data = user_year_playtime[user_year_playtime['user_id'] == top_user_id]

  # Prepare playtime details
  playtime_details = [
      {'year': row["release_year"], 'hours': round(row["playtime_forever"], 2)}
      for _, row in top_user_data.iterrows()
  ]

  # Return user details dictionary
  return {
      "genre": genero,
      "user_id": top_user_id,
      "Hours played": playtime_details
  }

# %%
UserForGenre('Action')
# Out:
# {'genre': 'Action',
#  'user_id': 'shinomegami',
#  'Hours played': [{'year': 1988, 'hours': 2.27},
#   {'year': 1991, 'hours': 0.0},
#   {'year': 1992, 'hours': 0.0},
#   {'year': 1993, 'hours': 0.0},
#   {'year': 1994, 'hours': 0.0},
#   {'year': 1995, 'hours': 0.03},
#   {'year': 1996, 'hours': 19.35},
#   {'year': 1997, 'hours': 1.65},
#   {'year': 1998, 'hours': 61.93},
#   {'year': 1999, 'hours': 5.03},
#   {'year': 2000, 'hours': 159.53},
#   {'year': 2001, 'hours': 40.48},
#   {'year': 2002, 'hours': 0.0},
#   {'year': 2003, 'hours': 8879.27},
#   {'year': 2004, 'hours': 2.0},
#   {'year': 2005, 'hours': 5.72},
#   {'year': 2006, 'hours': 34.05},
#   {'year': 2007, 'hours': 1139.23},
#   {'year': 2008, 'hours': 3.0},
#   {'year': 2009, 'hours': 3496.75},
#   {'year': 2010, 'hours': 156.75},
#   {'year': 2011, 'hours': 1483.1},
#   {'year': 2012, 'hours': 300.65},
#   {'year': 2013, 'hours': 2427.27},
#   {'year': 2014, 'hours': 1490.75},
#   {'year': 2015, 'hours': 1686.15},
#   {'year': 2016, 'hours': 709.38},
#   {'year': 2017, 'hours': 2.25}]}
